# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression, Ridge, RidgeCV, Lasso, LassoCV, ElasticNet, ElasticNetCV, LogisticRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score, cross_validate, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,plot_confusion_matrix, f1_score

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

from sklearn.pipeline import Pipeline

import imblearn
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

from sklearn.tree import DecisionTreeClassifier

# %%
from base_model_eval import base_model_eval

# %% [markdown]
# Data without feature transformations

# %%
# Import data with 5 quality labels (no transformations)
white_wine = pd.read_csv('../transformed_wine_data/white_wine_5Q.csv')
red_wine = pd.read_csv('../transformed_wine_data/red_wine_5Q.csv')


# Import data with 3 quality labels (no transformations)
white_wine_3Q = pd.read_csv('../transformed_wine_data/white_wine_3Q.csv')
red_wine_3Q = pd.read_csv('../transformed_wine_data/red_wine_3Q.csv')


# X and y values for white and red wine – 5 quality labels (no transformations)
X_white = white_wine.drop(['quality_label', 'quality', 'type'], axis = 1)
y_white = white_wine['quality_label']

X_red = red_wine.drop(['quality_label', 'quality', 'type'], axis = 1)
y_red = red_wine['quality_label']


# X and y values for white and red wine – 3 quality labels (no transformations)
X_white_3Q = white_wine_3Q.drop(['quality_label', 'quality', 'type'], axis = 1)
y_white_3Q = white_wine_3Q['quality_label']

X_red_3Q = red_wine_3Q.drop(['quality_label', 'quality', 'type'], axis = 1)
y_red_3Q = red_wine_3Q['quality_label']

# %%
base_model_eval(X_white, y_white)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/68/lmdx_4hd4msbstk8y2t5phyh0000gn/T/ipykernel_84781/3134523715.py in <module>
# ----> 1 base_model_eval(X_white, y_white)
#
# ~/Documents/CodeAcademyBerlin/wine_analysis/ML-Classification/base_model_eval.py in base_model_eval(X_white, y_white)
#      60
# ...

# %%
base_model_eval(X_red, y_red)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/68/lmdx_4hd4msbstk8y2t5phyh0000gn/T/ipykernel_84781/2456287280.py in <module>
# ----> 1 base_model_eval(X_red, y_red)
#
# ~/Documents/CodeAcademyBerlin/wine_analysis/ML-Classification/base_model_eval.py in base_model_eval(X_white, y_white)
#      60
#      61         fig, ax = plt.subplots(figsize=(5, 5))
# ---> 62         ax.title(f'{name}')
#      63         plot_confusion_matrix(base_model,scaled_X_test,y_test, ax = ax)
#      64         plt.xticks (rotation = 90)
#
# TypeError: 'Text' object is not callable

# %%
base_model_eval(X_white_3Q, y_white_3Q)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# ...

# %%
base_model_eval(X_red_3Q, y_red_3Q)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# ...

# %% [markdown]
# Data with feature transformations

# %%
# Import data with 4 quality labels
white_wine_trans = pd.read_csv('transformed_wine_data/white_wine_trans.csv')
red_wine_trans = pd.read_csv('transformed_wine_data/red_wine_trans.csv')


# Import data with 3 quality labels
white_wine_trans_3Q = pd.read_csv('transformed_wine_data/white_wine_trans_3Q.csv')
red_wine_trans_3Q = pd.read_csv('transformed_wine_data/red_wine_trans_3Q.csv')


# X and y values for white and red wine – 4 quality labels
X_white = white_wine_trans.drop(['quality_label', 'quality', 'type'], axis = 1)
y_white = white_wine_trans['quality_label']

X_red = red_wine_trans.drop(['quality_label', 'quality', 'type'], axis = 1)
y_red = red_wine_trans['quality_label']


# X and y values for white and red wine – 3 quality labels
X_white_3Q = white_wine_trans_3Q.drop(['quality_label', 'quality', 'type'], axis = 1)
y_white_3Q = white_wine_trans_3Q['quality_label']

X_red_3Q = red_wine_trans_3Q.drop(['quality_label', 'quality', 'type'], axis = 1)
y_red_3Q = red_wine_trans_3Q['quality_label']

# %%
base_model_eval(X_white, y_white)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# ...

# %%
base_model_eval(X_red, y_red)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# ...

# %%
base_model_eval(X_white_3Q, y_white_3Q);
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# ...

# %%
base_model_eval(X_red_3Q, y_red_3Q)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# ...

# %%
fig, ax = plt.subplots()
ax.plot([1,2,3], [2,4,6])
plt.title('hi')
plt.show()
